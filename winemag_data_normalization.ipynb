# %% [markdown]
# ## 1. Setting Up MySQL Environment

# %%
# install and start mysql server
# !apt -qq update > /dev/null
# !apt -y -qq install mysql-server > /dev/null
# !/etc/init.d/mysql restart > /dev/null

# enable data loading from a csv file into a table, only required for colab
# !echo -e "[mysqld]\nsecure_file_priv = \"\"" >> /etc/my.cnf
# !/etc/init.d/mysql restart > /dev/null
# !mysql -e "SET GLOBAL local_infile=true;"

# mount gdrive, required for downloaded dataset (or sql data dump)
import os
from google.colab import drive
drive.mount("/content/drive")

# install gdown, required for download file from GDrive
# !pip -q install gdown
import gdown

# install sql magic, required for running sql commands in jupyter notebook
# !pip install -q ipython-sql==0.5.0
# install mysql python connector
# !pip install -q pymysql==1.1.0
# install sqlalchemy
# !pip install -q sqlalchemy==2.0.20
# enable sql magic in the notebook
# %reload_ext sql

# queries are returned in the pandas format
# %config SqlMagic.autopandas=True

import pandas as pd
# maximum # of rows to be rendered
pd.set_option('display.max_rows', 25)
# Out:
# WARNING: apt does not have a stable CLI interface. Use with caution in scripts.
#
#
# WARNING: apt does not have a stable CLI interface. Use with caution in scripts.
#
# su: warning: cannot change directory to /nonexistent: No such file or directory
# su: warning: cannot change directory to /nonexistent: No such file or directory
# Mounted at /content/drive
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 7.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.8/44.8 kB 570.5 kB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.0/3.0 MB 12.8 MB/s eta 0:00:00

# %% [markdown]
# ## 2. Repository Structure and Environment Parameters

# %%
# project name
os.environ["PROJECT_NAME"] = "wine_reviews"
# database name
os.environ["DATABASE_NAME"] = os.getenv("PROJECT_NAME")

# mysql credentials
os.environ["MYSQL_USER"] = "francis"
os.environ["MYSQL_USER_PASSWORD"] = "california"

# %%
# set folder paths in gdrive for the coursework
os.environ["CODER_HOME"] = "/content"
os.environ["PROJECTS"] = os.getenv("CODER_HOME") + "/project"
os.environ["PROJECT_HOME"] = os.getenv("PROJECTS") + "/" + os.getenv("PROJECT_NAME")
os.environ["DATA_PATH"] = os.getenv("PROJECT_HOME") + "/data"
os.environ["SCRIPT_PATH"] = os.getenv("PROJECT_HOME") + "/scripts"

# heirachically create project folders in local if not exist
# !mkdir -p $CODER_HOME
# !mkdir -p $PROJECTS
# !mkdir -p $PROJECT_HOME
# !mkdir -p $DATA_PATH
# !mkdir -p $SCRIPT_PATH

# set folder paths on gdrive for the coursework
os.environ["GD_COURSE_HOME"] = "/content/drive/MyDrive/Databases"
os.environ["GD_PROJECT_HOME"] = os.getenv("GD_COURSE_HOME") + "/" + os.getenv("PROJECT_NAME")
os.environ["GD_DATA_PATH"] = os.getenv("GD_PROJECT_HOME") + "/data"
os.environ["GD_SCRIPT_PATH"] = os.getenv("GD_PROJECT_HOME") + "/scripts"

# heirachically create project folders in gdrive if not exist
# !mkdir -p $GD_COURSE_HOME
# !mkdir -p $GD_PROJECT_HOME
# !mkdir -p $GD_DATA_PATH
# !mkdir -p $GD_SCRIPT_PATH

# %% [markdown]
# #####Verify the project folders are created both in local and GDrive.

# %%
# !ls -d $PROJECT_HOME/*
# Out:
# /content/project/wine_reviews/data  /content/project/wine_reviews/scripts

# %%
# !ls -d $GD_PROJECT_HOME/*
# Out:
# /content/drive/MyDrive/Databases/wine_reviews/data
# /content/drive/MyDrive/Databases/wine_reviews/scripts

# %% [markdown]
# #####To ease code transfer, we create a symbolic link between the HOME folders of Google Colab and Coursera Lab environments, which are <code>/content</code> and <code>/home/coder</code>, respectively

# %%
# !ln -s /content /home/coder

# %% [markdown]
# Verify the symlink is created correctly.

# %%
# !ls /content
# Out:
# drive  project	sample_data

# %%
# !ls /home/coder
# Out:
# drive  project	sample_data

# %% [markdown]
# ## 3. Dataset: Wine Magazine Reviews
#
# *   Dataset description: This is a dataset of wine reviews derived from data that was scraped from WineEnthusiast, an online magazine, "the premier destination for all things wine. From acclaimed wine ratings and reads to wine storage, glasses and more." - stated on the website: https://www.wineenthusiast.com/ratings/.
# * Search the official Wine Enthusiast Ratings database to find the best reviews for all your favorite wine, beer and spirits. Our team of reviewers blind taste more than 24,000 wines from across the globe every year. Our free access to wine, beer and spirit ratings can be filtered by score, price, vintage, grape variety and region, making it a flexible tool to easily find your next favorite bottle.
# * Data fields:
#        ['Unnamed: 0', 'country', 'description', 'designation', 'points', 'price', 'province', 'region_1', 'region_2', 'taster_name',
#        'taster_twitter_handle', 'title', 'variety', 'winery']
# *   Link to data (kaggle): https://www.kaggle.com/datasets/zynicide/wine-reviews
#
# The dataset was downloaded and shared through a Google Drive URL. We download the file and place it in our GDrive, which will subsequently be used for normalisation and data ingestion.
#
# *   GDrive link: https://drive.google.com/file/d/10rjTR4vst1oBMR3D5zIiKxs85HDV7j_2/view?usp=sharing
#
#
#
# Upload the csv data to GDRIVE and place inside GD_PROJECT_HOME/data folder.

# %%
# set download path for our data file
# URL for our dataset, winemag-data.csv
URL = "https://drive.google.com/file/d/10rjTR4vst1oBMR3D5zIiKxs85HDV7j_2/view?usp=sharing"
FILE_PATH = "https://drive.google.com/uc?export=download&id=" + URL.split("/")[-2]

# set upload path for winemag-data.csv
os.environ["SRC_FILE_NAME"] = "winemag-data.csv"
SRC_FILE_PATH = os.getenv("GD_DATA_PATH") + "/" + os.getenv("SRC_FILE_NAME")

# download and upload the csv data to GDRIVE and place inside GD_PROJECT_HOME/data folder.
# in this case, it will be at Databases/wine_reviews/data
gdown.download(FILE_PATH, SRC_FILE_PATH, quiet=True)
# Out:
# '/content/drive/MyDrive/Databases/wine_reviews/data/winemag-data.csv'

# %%
# !ls $GD_DATA_PATH
# Out:
# winemag-data.csv  winemag-records.csv

# %% [markdown]
# ## 4. ER Diagram and Relational Schema
#
# ### Relational Schema
# * https://dbdiagram.io/d/winemag-database-657c21b456d8064ca016ef3d

# %% [markdown]
# ## 5. Data Cleaning
# For this usecase, I will be dropping the first 'Unnamed:0' column, columns region_1, region_2, price, any rows with NaN values and duplicate rows. Then I will condense the table by retaining only the reviews with the highest points for each wine as there are multiple rows with the same review title but varying descriptions and points

# %%
SCRIPT_PATH = os.getenv("SCRIPT_PATH")
DATA_PATH = os.getenv("DATA_PATH")

DATABASE_NAME = os.getenv("DATABASE_NAME")
MYSQL_USER_NAME = os.getenv("MYSQL_USER")
MYSQL_USER_PASSWORD = os.getenv("MYSQL_USER_PASSWORD")

# %%
import pandas as pd
pd.options.mode.chained_assignment = None

df = pd.read_csv(SRC_FILE_PATH)
df.head()
# Out:
#    Unnamed: 0   country                                        description  \
# 0           0     Italy  Aromas include tropical fruit, broom, brimston...
# 1           1  Portugal  This is ripe and fruity, a wine that is smooth...
# 2           2        US  Tart and snappy, the flavors of lime flesh and...
# 3           3        US  Pineapple rind, lemon pith and orange blossom ...
# 4           4        US  Much like the regular bottling from 2012, this...
#
#                           designation  points  price           province  \
# 0                        Vulkà Bianco      87    NaN  Sicily & Sardinia
# 1                            Avidagos      87   15.0              Douro
# 2                                 NaN      87   14.0             Oregon
# 3                Reserve Late Harvest      87   13.0           Michigan
# 4  Vintner's Reserve Wild Child Block      87   65.0             Oregon
#
#               region_1           region_2         taster_name  \
# 0                 Etna                NaN       Kerin O’Keefe
# 1                  NaN                NaN          Roger Voss
# 2    Willamette Valley  Willamette Valley        Paul Gregutt
# 3  Lake Michigan Shore                NaN  Alexander Peartree
# 4    Willamette Valley  Willamette Valley        Paul Gregutt
#
#   taster_twitter_handle                                              title  \
# 0          @kerinokeefe                  Nicosia 2013 Vulkà Bianco  (Etna)
# 1            @vossroger      Quinta dos Avidagos 2011 Avidagos Red (Douro)
# 2           @paulgwine       Rainstorm 2013 Pinot Gris (Willamette Valley)
# 3                   NaN  St. Julian 2013 Reserve Late Harvest Riesling ...
# 4           @paulgwine   Sweet Cheeks 2012 Vintner's Reserve Wild Child...
#
#           variety               winery
# 0     White Blend              Nicosia
# 1  Portuguese Red  Quinta dos Avidagos
# 2      Pinot Gris            Rainstorm
# 3        Riesling           St. Julian
# 4      Pinot Noir         Sweet Cheeks

# %% [markdown]
# #### Slice first column 'Unnamed:0'

# %%
df2 = df.iloc[:,1:]
df2.head()
# Out:
#     country                                        description  \
# 0     Italy  Aromas include tropical fruit, broom, brimston...
# 1  Portugal  This is ripe and fruity, a wine that is smooth...
# 2        US  Tart and snappy, the flavors of lime flesh and...
# 3        US  Pineapple rind, lemon pith and orange blossom ...
# 4        US  Much like the regular bottling from 2012, this...
#
#                           designation  points  price           province  \
# 0                        Vulkà Bianco      87    NaN  Sicily & Sardinia
# 1                            Avidagos      87   15.0              Douro
# 2                                 NaN      87   14.0             Oregon
# 3                Reserve Late Harvest      87   13.0           Michigan
# 4  Vintner's Reserve Wild Child Block      87   65.0             Oregon
#
#               region_1           region_2         taster_name  \
# 0                 Etna                NaN       Kerin O’Keefe
# 1                  NaN                NaN          Roger Voss
# 2    Willamette Valley  Willamette Valley        Paul Gregutt
# 3  Lake Michigan Shore                NaN  Alexander Peartree
# 4    Willamette Valley  Willamette Valley        Paul Gregutt
#
#   taster_twitter_handle                                              title  \
# 0          @kerinokeefe                  Nicosia 2013 Vulkà Bianco  (Etna)
# 1            @vossroger      Quinta dos Avidagos 2011 Avidagos Red (Douro)
# 2           @paulgwine       Rainstorm 2013 Pinot Gris (Willamette Valley)
# 3                   NaN  St. Julian 2013 Reserve Late Harvest Riesling ...
# 4           @paulgwine   Sweet Cheeks 2012 Vintner's Reserve Wild Child...
#
#           variety               winery
# 0     White Blend              Nicosia
# 1  Portuguese Red  Quinta dos Avidagos
# 2      Pinot Gris            Rainstorm
# 3        Riesling           St. Julian
# 4      Pinot Noir         Sweet Cheeks

# %% [markdown]
# #### Drop columns region_1, region_2 and price
# due to large number of empty values, and duplicated prices

# %%
df2.isna().sum()
# Out:
# country                     63
# description                  0
# designation              37465
# points                       0
# price                     8996
# province                    63
# region_1                 21247
# region_2                 79460
# taster_name              26244
# taster_twitter_handle    31213
# title                        0
# variety                      1
# winery                       0
# dtype: int64

# %%
df3 = df2.drop(['region_1','region_2', 'price'], axis=1)
df3.head()
# Out:
#     country                                        description  \
# 0     Italy  Aromas include tropical fruit, broom, brimston...
# 1  Portugal  This is ripe and fruity, a wine that is smooth...
# 2        US  Tart and snappy, the flavors of lime flesh and...
# 3        US  Pineapple rind, lemon pith and orange blossom ...
# 4        US  Much like the regular bottling from 2012, this...
#
#                           designation  points           province  \
# 0                        Vulkà Bianco      87  Sicily & Sardinia
# 1                            Avidagos      87              Douro
# 2                                 NaN      87             Oregon
# 3                Reserve Late Harvest      87           Michigan
# 4  Vintner's Reserve Wild Child Block      87             Oregon
#
#           taster_name taster_twitter_handle  \
# 0       Kerin O’Keefe          @kerinokeefe
# 1          Roger Voss            @vossroger
# 2        Paul Gregutt           @paulgwine
# 3  Alexander Peartree                   NaN
# 4        Paul Gregutt           @paulgwine
#
#                                                title         variety  \
# 0                  Nicosia 2013 Vulkà Bianco  (Etna)     White Blend
# 1      Quinta dos Avidagos 2011 Avidagos Red (Douro)  Portuguese Red
# 2      Rainstorm 2013 Pinot Gris (Willamette Valley)      Pinot Gris
# 3  St. Julian 2013 Reserve Late Harvest Riesling ...        Riesling
# 4  Sweet Cheeks 2012 Vintner's Reserve Wild Child...      Pinot Noir
#
#                 winery
# 0              Nicosia
# 1  Quinta dos Avidagos
# 2            Rainstorm
# 3           St. Julian
# 4         Sweet Cheeks

# %% [markdown]
# #### Drop rows with empty values

# %%
df4 = df3.dropna()
df4.head()
# Out:
#     country                                        description  \
# 0     Italy  Aromas include tropical fruit, broom, brimston...
# 1  Portugal  This is ripe and fruity, a wine that is smooth...
# 4        US  Much like the regular bottling from 2012, this...
# 5     Spain  Blackberry and raspberry aromas show a typical...
# 6     Italy  Here's a bright, informal red that opens with ...
#
#                           designation  points           province  \
# 0                        Vulkà Bianco      87  Sicily & Sardinia
# 1                            Avidagos      87              Douro
# 4  Vintner's Reserve Wild Child Block      87             Oregon
# 5                        Ars In Vitro      87     Northern Spain
# 6                             Belsito      87  Sicily & Sardinia
#
#          taster_name taster_twitter_handle  \
# 0      Kerin O’Keefe          @kerinokeefe
# 1         Roger Voss            @vossroger
# 4       Paul Gregutt           @paulgwine
# 5  Michael Schachner           @wineschach
# 6      Kerin O’Keefe          @kerinokeefe
#
#                                                title             variety  \
# 0                  Nicosia 2013 Vulkà Bianco  (Etna)         White Blend
# 1      Quinta dos Avidagos 2011 Avidagos Red (Douro)      Portuguese Red
# 4  Sweet Cheeks 2012 Vintner's Reserve Wild Child...          Pinot Noir
# 5  Tandem 2011 Ars In Vitro Tempranillo-Merlot (N...  Tempranillo-Merlot
# 6   Terre di Giurfo 2013 Belsito Frappato (Vittoria)            Frappato
#
#                 winery
# 0              Nicosia
# 1  Quinta dos Avidagos
# 4         Sweet Cheeks
# 5               Tandem
# 6      Terre di Giurfo

# %% [markdown]
# Check that final dataframe has no empty values

# %%
df4.isna().sum()
# Out:
# country                  0
# description              0
# designation              0
# points                   0
# province                 0
# taster_name              0
# taster_twitter_handle    0
# title                    0
# variety                  0
# winery                   0
# dtype: int64

# %%
df4.columns
# Out:
# Index(['country', 'description', 'designation', 'points', 'province',
#        'taster_name', 'taster_twitter_handle', 'title', 'variety', 'winery'],
#       dtype='object')

# %% [markdown]
# #### Check for duplicates and drop duplicate rows
# df_dup lists duplicated columns along with the column size indicating the number of duplicates

# %%
df_dup = df4.groupby(df4.columns.tolist(), as_index=False).size()
df_dup.loc[df_dup['size'] > 1]
# Out:
#          country                                        description  \
# 12     Argentina  A bit of dust and leather for openers, with sh...
# 34     Argentina  A deep, developed wine with cola, licorice and...
# 41     Argentina  A fairly oaky bouquet with overt wood grain, v...
# 51     Argentina  A full, oily nose with aromas of orange blosso...
# 58     Argentina  A heady but attractive bouquet of marzipan, ba...
# ...          ...                                                ...
# 65174    Uruguay  Inky cool herbal black-fruit aromas set up a c...
# 65175    Uruguay  Inky purple in color, with herbal, minty, toas...
# 65179    Uruguay  No kidding that this was aged in oak (Criado e...
# 65199    Uruguay  Rusty in color, this maturing Tannat-led blend...
# 65205    Uruguay  This blend of Pinot Noir and Chardonnay is ora...
#
#                             designation  points          province  \
# 12                              Altosur      85  Mendoza Province
# 34              Henry Gran Guarda No. 1      92  Mendoza Province
# 41                            Encuentro      88  Mendoza Province
# 51                       Las Compuertas      86  Mendoza Province
# 58              Single Vineyard Reserva      92  Mendoza Province
# ...                                 ...     ...               ...
# 65174            100 Años Viñas Mendoza      87        Montevideo
# 65175                        Las Brujas      87         Canelones
# 65179                   Criado en Roble      87         Canelones
# 65199   Preludio Barrel Select Lot N°92      87           Juanico
# 65205  Reserve Collection Blanc de Noir      84         Canelones
#
#              taster_name taster_twitter_handle  \
# 12     Michael Schachner           @wineschach
# 34     Michael Schachner           @wineschach
# 41     Michael Schachner           @wineschach
# 51     Michael Schachner           @wineschach
# 58     Michael Schachner           @wineschach
# ...                  ...                   ...
# 65174  Michael Schachner           @wineschach
# 65175  Michael Schachner           @wineschach
# 65179  Michael Schachner           @wineschach
# 65199  Michael Schachner           @wineschach
# 65205  Michael Schachner           @wineschach
#
#                                                    title             variety  \
# 12        Finca Sophenia 2007 Altosur Malbec (Tupungato)              Malbec
# 34     Lagarde 2007 Henry Gran Guarda No. 1 Red (Mend...           Red Blend
# 41     Rutini 2011 Encuentro Cabernet Sauvignon (Mend...  Cabernet Sauvignon
# 51     Luigi Bosca 2014 Las Compuertas Riesling (Lujá...            Riesling
# 58     Lamadrid 2012 Single Vineyard Reserva Malbec (...              Malbec
# ...                                                  ...                 ...
# 65174  Gimenez Mendez 2015 100 Años Viñas Mendoza Mal...              Malbec
# 65175     Gimenez Mendez 2015 Las Brujas Red (Canelones)           Red Blend
# 65179  Montes Toscanini 2015 Criado en Roble Tannat (...              Tannat
# 65199  Familia Deicas 2009 Preludio Barrel Select Lot...           Red Blend
# 65205  Marichal 2015 Reserve Collection Blanc de Noir...                Rosé
#
#                  winery  size
# 12       Finca Sophenia     2
# 34              Lagarde     2
# 41               Rutini     2
# 51          Luigi Bosca     2
# 58             Lamadrid     2
# ...                 ...   ...
# 65174    Gimenez Mendez     2
# 65175    Gimenez Mendez     2
# 65179  Montes Toscanini     2
# 65199    Familia Deicas     2
# 65205          Marichal     2
#
# [5849 rows x 11 columns]

# %%
df5 = df4.drop_duplicates()
df5
# Out:
#          country                                        description  \
# 0          Italy  Aromas include tropical fruit, broom, brimston...
# 1       Portugal  This is ripe and fruity, a wine that is smooth...
# 4             US  Much like the regular bottling from 2012, this...
# 5          Spain  Blackberry and raspberry aromas show a typical...
# 6          Italy  Here's a bright, informal red that opens with ...
# ...          ...                                                ...
# 129963    Israel  A bouquet of black cherry, tart cranberry and ...
# 129964    France  Initially quite muted, this wine slowly develo...
# 129965    France  While it's rich, this beautiful dry wine also ...
# 129968    France  Well-drained gravel soil gives this wine its c...
# 129970    France  Big, rich and off-dry, this is powered by inte...
#
#                                designation  points           province  \
# 0                             Vulkà Bianco      87  Sicily & Sardinia
# 1                                 Avidagos      87              Douro
# 4       Vintner's Reserve Wild Child Block      87             Oregon
# 5                             Ars In Vitro      87     Northern Spain
# 6                                  Belsito      87  Sicily & Sardinia
# ...                                    ...     ...                ...
# 129963                            Oak Aged      90            Galilee
# 129964        Domaine Saint-Rémy Herrenweg      90             Alsace
# 129965         Seppi Landmann Vallée Noble      90             Alsace
# 129968                               Kritt      90             Alsace
# 129970       Lieu-dit Harth Cuvée Caroline      90             Alsace
#
#               taster_name taster_twitter_handle  \
# 0           Kerin O’Keefe          @kerinokeefe
# 1              Roger Voss            @vossroger
# 4            Paul Gregutt           @paulgwine
# 5       Michael Schachner           @wineschach
# 6           Kerin O’Keefe          @kerinokeefe
# ...                   ...                   ...
# 129963      Mike DeSimone        @worldwineguys
# 129964         Roger Voss            @vossroger
# 129965         Roger Voss            @vossroger
# 129968         Roger Voss            @vossroger
# 129970         Roger Voss            @vossroger
#
#                                                     title             variety  \
# 0                       Nicosia 2013 Vulkà Bianco  (Etna)         White Blend
# 1           Quinta dos Avidagos 2011 Avidagos Red (Douro)      Portuguese Red
# 4       Sweet Cheeks 2012 Vintner's Reserve Wild Child...          Pinot Noir
# 5       Tandem 2011 Ars In Vitro Tempranillo-Merlot (N...  Tempranillo-Merlot
# 6        Terre di Giurfo 2013 Belsito Frappato (Vittoria)            Frappato
# ...                                                   ...                 ...
# 129963  Dalton 2012 Oak Aged Cabernet Sauvignon (Galilee)  Cabernet Sauvignon
# 129964  Domaine Ehrhart 2013 Domaine Saint-Rémy Herren...      Gewürztraminer
# 129965  Domaine Rieflé-Landmann 2013 Seppi Landmann Va...          Pinot Gris
# 129968  Domaine Gresser 2013 Kritt Gewurztraminer (Als...      Gewürztraminer
# 129970  Domaine Schoffit 2012 Lieu-dit Harth Cuvée Car...      Gewürztraminer
#
#                          winery
# 0                       Nicosia
# 1           Quinta dos Avidagos
# 4                  Sweet Cheeks
# 5                        Tandem
# 6               Terre di Giurfo
# ...                         ...
# 129963                   Dalton
# 129964          Domaine Ehrhart
# 129965  Domaine Rieflé-Landmann
# 129968          Domaine Gresser
# 129970         Domaine Schoffit
#
# [65217 rows x 10 columns]

# %% [markdown]
# df5 is 5526 rows smaller than df4, equal to the number of duplicates as seen by the number of rows in df_dup. Hence duplicate rows have been removed - as verified below:

# %%
duplicates = df5[df5.duplicated()]
duplicates
# Out:
# Empty DataFrame
# Columns: [country, description, designation, points, province, taster_name, taster_twitter_handle, title, variety, winery]
# Index: []

# %% [markdown]
# #### Retain only reviews with highest points from duplicate reviews

# %%
df6 = df5.loc[df5.groupby('title')['points'].idxmax()]
df6
# Out:
#          country                                        description  \
# 63807      Spain  The previous two years we did not find this wi...
# 55163      Spain  Spiced apple and toast aromas are clean and di...
# 33657      Spain  Clean, fresh apple aromas and a minerally, cit...
# 20319      Spain  A dusty, yeasty nose is simplistic but friendl...
# 122898        US  Juicy and fresh, this deeply colored wine offe...
# ...          ...                                                ...
# 2579          US  Coming from one of the state's premier Syrah v...
# 5926          US  The berry, herb and coffee aromas are light an...
# 128023        US  Pour Me is a new label produced by the talente...
# 70504   Slovenia  This orange-style wine is dark straw in color ...
# 70505   Slovenia  A mix of bright red cherry, blueberry, thyme, ...
#
#                                               designation  points    province  \
# 63807                                                Rosé      82   Catalonia
# 55163                                                Brut      87   Catalonia
# 33657   Cygnus Brut Nature Reserva Made With Organic G...      89   Catalonia
# 20319                                                Rosé      86   Catalonia
# 122898                             All Profits to Charity      89  California
# ...                                                   ...     ...         ...
# 2579                                     Boushey Vineyard      89  Washington
# 5926                                          Fred Estate      88  Washington
# 128023                                            Pour Me      89  Washington
# 70504                                             Grganja      90        Kras
# 70505                                             Izbrani      90        Kras
#
#               taster_name taster_twitter_handle  \
# 63807   Michael Schachner           @wineschach
# 55163   Michael Schachner           @wineschach
# 33657   Michael Schachner           @wineschach
# 20319   Michael Schachner           @wineschach
# 122898         Jim Gordon      @gordone_cellars
# ...                   ...                   ...
# 2579     Sean P. Sullivan         @wawinereport
# 5926     Sean P. Sullivan         @wawinereport
# 128023       Paul Gregutt           @paulgwine
# 70504        Jeff Jenssen        @worldwineguys
# 70505        Jeff Jenssen        @worldwineguys
#
#                                                     title             variety  \
# 63807        1+1=3 2008 Rosé Cabernet Sauvignon (Penedès)  Cabernet Sauvignon
# 55163                      1+1=3 NV Brut Sparkling (Cava)     Sparkling Blend
# 33657   1+1=3 NV Cygnus Brut Nature Reserva Made With ...     Sparkling Blend
# 20319                      1+1=3 NV Rosé Sparkling (Cava)     Sparkling Blend
# 122898  100 Percent Wine 2012 All Profits to Charity R...           Red Blend
# ...                                                   ...                 ...
# 2579    àMaurice 2014 Boushey Vineyard Syrah (Yakima V...               Syrah
# 5926    àMaurice 2014 Fred Estate Syrah (Walla Walla V...               Syrah
# 128023     àMaurice NV Pour Me Red (Columbia Valley (WA))           Red Blend
# 70504                  Štoka 2011 Grganja Vitovska (Kras)            Vitovska
# 70505                     Štoka 2011 Izbrani Teran (Kras)               Teran
#
#                   winery
# 63807              1+1=3
# 55163              1+1=3
# 33657              1+1=3
# 20319              1+1=3
# 122898  100 Percent Wine
# ...                  ...
# 2579            àMaurice
# 5926            àMaurice
# 128023          àMaurice
# 70504              Štoka
# 70505              Štoka
#
# [64532 rows x 10 columns]

# %%
# Check that each title only has 1 row
df_reviews = df6[['title']].value_counts().reset_index(name='reviews')
df_reviews

#df_final['title'].value_counts()
# Out:
#                                                    title  reviews
# 0           1+1=3 2008 Rosé Cabernet Sauvignon (Penedès)        1
# 1      Naggiar 2012 Il Nonno Estate Reserve Red (Sier...        1
# 2      Naggiar 2011 Estate Grown Mourvèdre (Sierra Fo...        1
# 3          Naggiar 2011 Estate Malbec (Sierra Foothills)        1
# 4      Naggiar 2011 Estate Petite Sirah (Sierra Footh...        1
# ...                                                  ...      ...
# 64527  Domaine de la Sanglière 2014 Juliette Rosé (Me...        1
# 64528  Domaine de la Sanglière 2015 Breezette Rosé (C...        1
# 64529  Domaine de la Sanglière 2015 Cuvée Spéciale Ro...        1
# 64530  Domaine de la Sanglière 2015 Juliette Rosé (Me...        1
# 64531                    Štoka 2011 Izbrani Teran (Kras)        1
#
# [64532 rows x 2 columns]

# %%
df_reviews.loc[df_reviews['reviews'] > 1]
# Out:
# Empty DataFrame
# Columns: [title, reviews]
# Index: []

# %% [markdown]
# ### Condense data
# To only reviews with points in the upper quarter (max - (max-min)/4)

# %%
import numpy as np
max_points = max(df6['points'])
min_points = min(df6['points'])
q = max_points - (max_points-min_points)/4
q
# Out:
# 95.0

# %%
df_final = df6.loc[df6['points'] >= 95]
df_final
# Out:
#        country                                        description  \
# 99316    Italy  Here's a delicious red that opens with appeali...
# 27608    Italy  You'll need to swirl the glass a few times to ...
# 33841       US  Sourced from old-vine Bacchus and Weinbau frui...
# 99317       US  This splendid, resonant, beautifully detailed ...
# 83367       US  The best of a great flight of single-vineyard ...
# ...        ...                                                ...
# 126238      US  Pure Cabernet from some of Washington's oldest...
# 122571      US  Here the high alcohol does not obscure the lay...
# 114539      US  Clean and ripe raspberry notes are cut with co...
# 95555       US  This is a stunning Pinot Noir, especially from...
# 100010  France  A huge, ink-black wine with all the brooding m...
#
#                   designation  points            province    taster_name  \
# 99316           Vigna Piaggia      95             Tuscany  Kerin O’Keefe
# 27608             Praepositus      95  Northeastern Italy  Kerin O’Keefe
# 33841                 Reserve      97          Washington   Paul Gregutt
# 99317   Gran Moraine Vineyard      95              Oregon   Paul Gregutt
# 83367       Nicholas Vineyard      95              Oregon   Paul Gregutt
# ...                       ...     ...                 ...            ...
# 126238              Old Vines      95          Washington   Paul Gregutt
# 122571      Artist Series #18      95          Washington   Paul Gregutt
# 114539      McIntrye Vineyard      95          California  Matt Kettmann
# 95555    Bien Nacido Vineyard      95          California  Matt Kettmann
# 100010             Empreintes      95        Rhône Valley     Roger Voss
#
#        taster_twitter_handle  \
# 99316           @kerinokeefe
# 27608           @kerinokeefe
# 33841            @paulgwine
# 99317            @paulgwine
# 83367            @paulgwine
# ...                      ...
# 126238           @paulgwine
# 122571           @paulgwine
# 114539         @mattkettmann
# 95555          @mattkettmann
# 100010            @vossroger
#
#                                                     title  \
# 99316   Abbadia Ardenga 2012 Vigna Piaggia  (Brunello ...
# 27608   Abbazia di Novacella 2015 Praepositus Kerner (...
# 33841   Abeja 2007 Reserve Cabernet Sauvignon (Columbi...
# 99317   Aberrant Cellars 2014 Gran Moraine Vineyard Pi...
# 83367   Adelsheim 2009 Nicholas Vineyard Pinot Noir (C...
# ...                                                   ...
# 126238  Woodward Canyon 2007 Old Vines Cabernet Sauvig...
# 122571  Woodward Canyon 2009 Artist Series #18 Caberne...
# 114539  Wrath 2012 McIntrye Vineyard Pinot Noir (Santa...
# 95555   Zaca Mesa 2015 Bien Nacido Vineyard Pinot Noir...
# 100010       Éric & Jöel Durand 1999 Empreintes  (Cornas)
#
#                       variety                winery
# 99316              Sangiovese       Abbadia Ardenga
# 27608                  Kerner  Abbazia di Novacella
# 33841      Cabernet Sauvignon                 Abeja
# 99317              Pinot Noir      Aberrant Cellars
# 83367              Pinot Noir             Adelsheim
# ...                       ...                   ...
# 126238     Cabernet Sauvignon       Woodward Canyon
# 122571     Cabernet Sauvignon       Woodward Canyon
# 114539             Pinot Noir                 Wrath
# 95555              Pinot Noir             Zaca Mesa
# 100010  Rhône-style Red Blend    Éric & Jöel Durand
#
# [1405 rows x 10 columns]

# %%
# save the clean data to a csv file for data loading and ingestion
df_final.to_csv(f"{DATA_PATH}/winemag-records.csv", index=False)

# only in Colab, the csv files must be readable for group and other
# required for MySQL LOAD DATA INFILE
# !chmod g+r,o+r $DATA_PATH/*.csv

# %% [markdown]
# ## 6. Setting Up Database and User Creation (required for Web App)

# %% [markdown]
# **Step 1:**

# %%
# %%writefile $SCRIPT_PATH/setup-database.sql
# /* create a project database, and drop it first if it already exists */
# DROP DATABASE IF EXISTS wine_reviews;
# CREATE DATABASE wine_reviews;
#
# /* create a database user, called francis, and drop it first if it already exists */
# DROP USER IF EXISTS 'francis'@'%';
# CREATE USER 'francis'@'%' IDENTIFIED WITH mysql_native_password BY 'california';
#
# /* grant user access to the project data, which was created earlier */
# GRANT ALL ON wine_reviews.* TO 'francis'@'%';
#
# /* only for running in colab, grant user francis to server related configuration */
# GRANT SELECT ON mysql.* TO 'francis'@'%';
# Out:
# Writing /content/project/wine_reviews/scripts/setup-database.sql

# %% [markdown]
# **Step 2:** We run a SQL script, setup-database.sql, to create data, user and then grant the user access to the database. This way, it is easier for us to make changes to the code and just re-run the script without having to exhausively re-type in the shell.

# %%
# !mysql -t < /home/coder/project/wine_reviews/scripts/setup-database.sql

# %% [markdown]
# Only for Colab, we create a MySQL connection, which is required by Jupyter SQL magic.

# %%
connection = f"mysql+pymysql://{MYSQL_USER_NAME}:{MYSQL_USER_PASSWORD}@localhost/{DATABASE_NAME}"
# %sql $connection

# %% [markdown]
# **Step 3**: Verify that the database and user is created as expected.

# %%
# %%sql
# SHOW DATABASES;
# Out:
#  * mysql+pymysql://francis:***@localhost/wine_reviews
# 4 rows affected.
#              Database
# 0  information_schema
# 1               mysql
# 2  performance_schema
# 3        wine_reviews

# %%
# %%sql
# SELECT user, host
# FROM mysql.user;
# Out:
#  * mysql+pymysql://francis:***@localhost/wine_reviews
# 6 rows affected.
#                user       host
# 0           francis          %
# 1  debian-sys-maint  localhost
# 2  mysql.infoschema  localhost
# 3     mysql.session  localhost
# 4         mysql.sys  localhost
# 5              root  localhost

# %% [markdown]
# ## 7. Create Data Tables
#
#
# * The tables which have no dependencies shall be created first, followed by those with less dependencis and finally the one that has the most dependencies.
#   * From the relational schema, start from tables at the edges and then move inwards.
# * To drop a table, do the reverse. Drop the table which has the highest depedencies, followed by less and finally those that have no dependencies.
#   * Start from the inner most and then move outwards towards the edges.

# %% [markdown]
# **Step 1**: Iteratively add a <code>CREATE TABLE</code> SQL scripts in the following order:<code>Countries</code>, <code>Provinces</code>, <code>Wineries</code>, <code>Designations</code>,<code>Varieties</code>, <code>Tasters</code>, <code>Wines</code>, and <code>Reviews</code>.

# %%
# %%writefile $SCRIPT_PATH/create-tables.sql
# USE wine_reviews;
#
# DROP TABLE IF EXISTS Reviews;
# DROP TABLE IF EXISTS Varieties;
# DROP TABLE IF EXISTS Tasters;
# DROP TABLE IF EXISTS Locations;
#
# CREATE TABLE Locations (
#   location_id int AUTO_INCREMENT PRIMARY KEY,
#   country_name varchar(15) NOT NULL,
#   province_name varchar(35) NOT NULL,
#   winery_name varchar(55) NOT NULL,
#   designation_name varchar(90) NOT NULL
# );
#
# CREATE TABLE Tasters (
#   taster_id int AUTO_INCREMENT PRIMARY KEY,
#   taster_name varchar(20) NOT NULL,
#   taster_twitter_handle varchar(20) NOT NULL
# );
#
# CREATE TABLE Varieties (
#   variety_id int AUTO_INCREMENT PRIMARY KEY,
#   variety_name varchar(35) NOT NULL
# );
#
# CREATE TABLE Reviews (
#   review_id int AUTO_INCREMENT PRIMARY KEY,
#   title varchar(140) NOT NULL,
#   description text NOT NULL,
#   points int NOT NULL,
#   location_id int,
#   variety_id int,
#   taster_id int,
#   FOREIGN KEY (location_id) REFERENCES Locations (location_id),
#   FOREIGN KEY (variety_id) REFERENCES Varieties (variety_id),
#   FOREIGN KEY (taster_id) REFERENCES Tasters (taster_id)
# );
# Out:
# Writing /content/project/wine_reviews/scripts/create-tables.sql

# %% [markdown]
# **Step 2**: Run <code>create-tables.sql</code> script. This will create tables specified in the SQL script.

# %%
# !mysql -t < /home/coder/project/wine_reviews/scripts/create-tables.sql

# %% [markdown]
# **Step 3**: Verify if the tables are created correctly.

# %%
# %%sql
# SHOW TABLES;
# Out:
#  * mysql+pymysql://francis:***@localhost/wine_reviews
# 4 rows affected.
#   Tables_in_wine_reviews
# 0              Locations
# 1                Reviews
# 2                Tasters
# 3              Varieties

# %% [markdown]
# **Step 4**: Iterate back to **Step 1** until all the tables are created.

# %%
# %%sql
# DESCRIBE Reviews;
# Out:
#  * mysql+pymysql://francis:***@localhost/wine_reviews
# 7 rows affected.
#          Field          Type Null  Key Default           Extra
# 0    review_id           int   NO  PRI    None  auto_increment
# 1        title  varchar(140)   NO         None
# 2  description          text   NO         None
# 3       points           int   NO         None
# 4  location_id           int  YES  MUL    None
# 5   variety_id           int  YES  MUL    None
# 6    taster_id           int  YES  MUL    None

# %% [markdown]
# ## 8. Load Denormalised Data (required for Data Ingestion)
# We load denormalised data into the <code>wine_reviews</code> database, which will then be used for data ingestion to the tables created previously.

# %% [markdown]
# **Step 1**: Create a SQL sript which contains:
# * Create <code>denormalised</code> table for temporarily storing our denormalised data.
# * Load the denormalised data into the <code>denormalised</code> table.

# %%
# %%writefile $SCRIPT_PATH/load-dnorm-data.sql
# USE wine_reviews;
#
# DROP TABLE IF EXISTS denormalised;
# CREATE TABLE denormalised (
#     country VARCHAR(15),
#     description TEXT,
#     designation VARCHAR(90),
#     points INT,
#     province VARCHAR(35),
#     taster_name VARCHAR(20),
#     taster_twitter_handle VARCHAR(20),
#     title VARCHAR(140),
#     variety VARCHAR(35),
#     winery VARCHAR(55)
# );
#
# LOAD DATA INFILE '/home/coder/project/wine_reviews/data/winemag-records.csv'
# INTO TABLE denormalised
# FIELDS TERMINATED BY ','
# ENCLOSED BY '"'
# LINES TERMINATED BY '\n'
# IGNORE 1 LINES
# ;
# Out:
# Writing /content/project/wine_reviews/scripts/load-dnorm-data.sql

# %% [markdown]
# **Step 2**: Run <code>load-dnorm_data.sql</code> script. This will create tables specified in the SQL script, load the CSV data into the database and then pivot it into a tall table.

# %%
# !mysql -t < /home/coder/project/wine_reviews/scripts/load-dnorm-data.sql

# %% [markdown]
# **Step 3**: Verify if the data is correctly loaded and then pivoted as intended.

# %%
# %%sql
# SELECT DISTINCT *
# FROM denormalised;
# Out:
#  * mysql+pymysql://francis:***@localhost/wine_reviews
# 1405 rows affected.
#      country                                        description  \
# 0      Italy  Here's a delicious red that opens with appeali...
# 1      Italy  You'll need to swirl the glass a few times to ...
# 2         US  Sourced from old-vine Bacchus and Weinbau frui...
# 3         US  This splendid, resonant, beautifully detailed ...
# 4         US  The best of a great flight of single-vineyard ...
# ...      ...                                                ...
# 1400      US  Pure Cabernet from some of Washington's oldest...
# 1401      US  Here the high alcohol does not obscure the lay...
# 1402      US  Clean and ripe raspberry notes are cut with co...
# 1403      US  This is a stunning Pinot Noir, especially from...
# 1404  France  A huge, ink-black wine with all the brooding m...
#
#                 designation  points            province    taster_name  \
# 0             Vigna Piaggia      95             Tuscany  Kerin O’Keefe
# 1               Praepositus      95  Northeastern Italy  Kerin O’Keefe
# 2                   Reserve      97          Washington   Paul Gregutt
# 3     Gran Moraine Vineyard      95              Oregon   Paul Gregutt
# 4         Nicholas Vineyard      95              Oregon   Paul Gregutt
# ...                     ...     ...                 ...            ...
# 1400              Old Vines      95          Washington   Paul Gregutt
# 1401      Artist Series #18      95          Washington   Paul Gregutt
# 1402      McIntrye Vineyard      95          California  Matt Kettmann
# 1403   Bien Nacido Vineyard      95          California  Matt Kettmann
# 1404             Empreintes      95        Rhône Valley     Roger Voss
#
#      taster_twitter_handle                                              title  \
# 0             @kerinokeefe  Abbadia Ardenga 2012 Vigna Piaggia  (Brunello ...
# 1             @kerinokeefe  Abbazia di Novacella 2015 Praepositus Kerner (...
# 2              @paulgwine   Abeja 2007 Reserve Cabernet Sauvignon (Columbi...
# 3              @paulgwine   Aberrant Cellars 2014 Gran Moraine Vineyard Pi...
# 4              @paulgwine   Adelsheim 2009 Nicholas Vineyard Pinot Noir (C...
# ...                    ...                                                ...
# 1400           @paulgwine   Woodward Canyon 2007 Old Vines Cabernet Sauvig...
# 1401           @paulgwine   Woodward Canyon 2009 Artist Series #18 Caberne...
# 1402         @mattkettmann  Wrath 2012 McIntrye Vineyard Pinot Noir (Santa...
# 1403         @mattkettmann  Zaca Mesa 2015 Bien Nacido Vineyard Pinot Noir...
# 1404            @vossroger       Éric & Jöel Durand 1999 Empreintes  (Cornas)
#
#                     variety                winery
# 0                Sangiovese       Abbadia Ardenga
# 1                    Kerner  Abbazia di Novacella
# 2        Cabernet Sauvignon                 Abeja
# 3                Pinot Noir      Aberrant Cellars
# 4                Pinot Noir             Adelsheim
# ...                     ...                   ...
# 1400     Cabernet Sauvignon       Woodward Canyon
# 1401     Cabernet Sauvignon       Woodward Canyon
# 1402             Pinot Noir                 Wrath
# 1403             Pinot Noir             Zaca Mesa
# 1404  Rhône-style Red Blend    Éric & Jöel Durand
#
# [1405 rows x 10 columns]

# %% [markdown]
# ## 9. Ingest Data into the Normalised Tables
# We shall do it iteratively, i.e. ingesting data into table by table (one at a time) and also verifying it after the ingestion.
#
# How do we determine the order?
#
# * The tables which have no dependencies shall be ingested first, followed by those with less dependencis and finally the one that has the most dependencies.
#   * From our relational schema, we will start from tables at the edges and then moving inwards.
# * If we are to delete the data in a table, we will then have to do the reverse. We delete it from the table which has the highest depedencies, followed by less and finally those that have no dependencies.
#   * We will start from the inner most and then moving outwards towards the edges.
#
#   Iteratively incrementing SQL script for data ingestion in the following order:<code>Countries</code>, <code>Provinces</code>, <code>Wineries</code>, <code>Designations</code>,<code>Varieties</code>, <code>Tasters</code>, <code>Wines</code>, and <code>Reviews</code>.

# %% [markdown]
# **Step 1**: Before writing the data insertion script, we shall develop and try out the script to see if it creating the data as what required for the table. We shall procced in the following order:<code>Countries</code>, <code>Provinces</code>, <code>Wineries</code>, <code>Designations</code>,<code>Varieties</code>, <code>Tasters</code>, <code>Reviews</code>, and <code>Wines</code>.

# %%
# %%sql
# SELECT DISTINCT variety
# FROM denormalised d;
# Out:
#  * mysql+pymysql://francis:***@localhost/wine_reviews
# 83 rows affected.
#                variety
# 0           Sangiovese
# 1               Kerner
# 2   Cabernet Sauvignon
# 3           Pinot Noir
# 4               Tannat
# ..                 ...
# 78                Rosé
# 79        Pinot Bianco
# 80            Garnacha
# 81     Shiraz-Viognier
# 82      Tinta del Pais
#
# [83 rows x 1 columns]

# %% [markdown]
# **Step 2**: Create a SQL sript using <code>INSERT INTO</code> which contains data insertion to all the normalised tables.

# %%
# %%writefile $SCRIPT_PATH/ingest-data.sql
# USE wine_reviews;
#
# DELETE FROM Reviews;
# DELETE FROM Tasters;
# DELETE FROM Locations;
# DELETE FROM Varieties;
#
#
# -- Insert data into Varieties table
# INSERT INTO Varieties (variety_name)
# SELECT DISTINCT variety
# FROM denormalised;
#
# -- Insert data into Locations table
# INSERT INTO Locations (country_name, province_name, winery_name, designation_name)
# SELECT DISTINCT country, province, winery, designation
# FROM denormalised;
#
# -- Insert data into Tasters table
# INSERT INTO Tasters (taster_name, taster_twitter_handle)
# SELECT DISTINCT taster_name, taster_twitter_handle
# FROM denormalised;
#
# -- Insert data into Reviews table
# INSERT INTO Reviews (title, description, points, location_id, variety_id, taster_id)
# SELECT
#   title,
#   description,
#   points,
#   l.location_id,
#   v.variety_id,
#   t.taster_id
# FROM
#   denormalised d
#   JOIN Locations l ON d.country = l.country_name
#     AND d.province = l.province_name
#     AND d.winery = l.winery_name
#     AND d.designation = l.designation_name
#   JOIN Varieties v ON d.variety = v.variety_name
#   JOIN Tasters t ON d.taster_name = t.taster_name;
# Out:
# Writing /content/project/wine_reviews/scripts/ingest-data.sql

# %% [markdown]
# **Step 3**: Run <code>ingest-data.sql</code> script. This will create tables specified in the SQL script, load the CSV data into the database and then pivot it into a tall table.

# %%
# !mysql -t < /home/coder/project/wine_reviews/scripts/ingest-data.sql

# %% [markdown]
# **Step 4**: Verify if the data is correctly ingested into the table as intended.

# %%
# %%sql
# SELECT * FROM Reviews;
# Out:
#  * mysql+pymysql://francis:***@localhost/wine_reviews
# 1405 rows affected.
#       review_id                                              title  \
# 0             1  Abbadia Ardenga 2012 Vigna Piaggia  (Brunello ...
# 1             2  Abbazia di Novacella 2015 Praepositus Kerner (...
# 2             3  Abeja 2007 Reserve Cabernet Sauvignon (Columbi...
# 3             4  Aberrant Cellars 2014 Gran Moraine Vineyard Pi...
# 4             5  Adelsheim 2009 Nicholas Vineyard Pinot Noir (C...
# ...         ...                                                ...
# 1400       1401   Stolo 2014 Estate Syrah (San Luis Obispo County)
# 1401       1402  Trisaetum 2016 Ribbon Ridge Estate Dry Rieslin...
# 1402       1403  Venge 2013 Bone Ash Vineyard Cabernet Sauvigno...
# 1403       1404  Venge 2012 Bone Ash Vineyard Cabernet Sauvigno...
# 1404       1405  Williams Selyem 2012 Bucher Vineyard Pinot Noi...
#
#                                             description  points  location_id  \
# 0     Here's a delicious red that opens with appeali...      95            1
# 1     You'll need to swirl the glass a few times to ...      95            2
# 2     Sourced from old-vine Bacchus and Weinbau frui...      97            3
# 3     This splendid, resonant, beautifully detailed ...      95            4
# 4     The best of a great flight of single-vineyard ...      95            5
# ...                                                 ...     ...          ...
# 1400  This is possibly the most savory rendition of ...      96          989
# 1401  Stunningly good, this hits you with waves of f...      96         1050
# 1402  From the producer's own dry-farmed estate, thi...      95         1056
# 1403  From one of three estate-farmed vineyards belo...      95         1056
# 1404  This is beautifully lilting in preciously defi...      97         1091
#
#       variety_id  taster_id
# 0              1          1
# 1              2          1
# 2              3          2
# 3              4          2
# 4              4          2
# ...          ...        ...
# 1400          18          3
# 1401          14          2
# 1402           3          6
# 1403           3          6
# 1404           4          6
#
# [1405 rows x 7 columns]

# %% [markdown]
# **Step 5**: Iterate back to **Step 1** until we ingest data to all the tables.

# %% [markdown]
# ## Questions for Web App
# ### Queries

# %% [markdown]
# **Question 1**: Most popular wineries:

# %%
# %%sql
# SELECT
#   l.winery_name AS Winery,
#   CONCAT(l.country_name, ', ', l.province_name) AS Location,
#   COUNT(r.review_id) AS review_count,
#   AVG(r.points) AS avg_points
# FROM Locations l
# JOIN Reviews r ON l.location_id = r.location_id
# GROUP BY l.winery_name, location
# ORDER BY review_count DESC, avg_points DESC
# LIMIT 20;
# Out:
#  * mysql+pymysql://francis:***@localhost/wine_reviews
# 20 rows affected.
#                     Winery             Location  review_count avg_points
# 0          Williams Selyem       US, California            28    95.8571
# 1   Domaine Zind-Humbrecht       France, Alsace            20    95.5000
# 2                   Cayuse       US, Washington            15    96.1333
# 3                  Kracher  Austria, Burgenland            14    96.1429
# 4           Louis Roederer    France, Champagne            14    95.7857
# 5           Emmerich Knoll      Austria, Wachau            14    95.4286
# 6              F X Pichler      Austria, Wachau            14    95.1429
# 7                   Cayuse           US, Oregon            12    96.7500
# 8                 Wayfarer       US, California            12    96.1667
# 9              Bründlmayer     Austria, Kamptal            12    95.3333
# 10                  Lynmar       US, California            12    95.3333
# 11       Franz Hirtzberger      Austria, Wachau            11    95.1818
# 12            Gary Farrell       US, California            11    95.1818
# 13              Cavallotto      Italy, Piedmont            10    95.6000
# 14         Taylor Fladgate       Portugal, Port             9    96.0000
# 15             Betz Family       US, Washington             9    95.6667
# 16              K Vintners       US, Washington             9    95.5556
# 17                   Ramey       US, California             9    95.5556
# 18        Domaine Schoffit       France, Alsace             9    95.3333
# 19               Massolino      Italy, Piedmont             8    96.0000

# %% [markdown]
# **Question 2**: Find the Highest Rated Wines:

# %%
# %%sql
# SELECT
#   r.title,
#   r.description,
#   r.points,
#   l.country_name,
#   l.province_name,
#   l.winery_name,
#   l.designation_name,
#   v.variety_name,
#   t.taster_name,
#   t.taster_twitter_handle
# FROM Reviews r
# JOIN Locations l ON r.location_id = l.location_id
# JOIN Varieties v ON r.variety_id = v.variety_id
# JOIN Tasters t ON r.taster_id = t.taster_id
# WHERE r.points = (SELECT MAX(points) FROM Reviews);
# Out:
#  * mysql+pymysql://francis:***@localhost/wine_reviews
# 9 rows affected.
#                                                title  \
# 0  Biondi Santi 2010 Riserva  (Brunello di Montal...
# 1      Casa Ferreirinha 2008 Barca-Velha Red (Douro)
# 2  Cayuse 2008 Bionic Frog Syrah (Walla Walla Val...
# 3  Chambers Rosewood Vineyards NV Rare Muscat (Ru...
# 4  Charles Smith 2006 Royal City Syrah (Columbia ...
# 5      Quinta do Noval 2011 Nacional Vintage  (Port)
# 6                        Krug 2002 Brut  (Champagne)
# 7  Louis Roederer 2008 Cristal Vintage Brut  (Cha...
# 8  Salon 2006 Le Mesnil Blanc de Blancs Brut Char...
#
#                                          description  points country_name  \
# 0  This gorgeous, fragrant wine opens with classi...     100        Italy
# 1  This is the latest release of what has long be...     100     Portugal
# 2  Initially a rather subdued Frog; as if it has ...     100           US
# 3  This wine contains some material over 100 year...     100    Australia
# 4  In 2005 Charles Smith introduced three high-en...     100           US
# 5  A powerful and ripe wine, strongly influenced ...     100     Portugal
# 6  This is a fabulous wine from the greatest Cham...     100       France
# 7  This latest incarnation of the famous brand is...     100       France
# 8  This new release from a great vintage for Char...     100       France
#
#   province_name                  winery_name                designation_name  \
# 0       Tuscany                 Biondi Santi                         Riserva
# 1         Douro             Casa Ferreirinha                     Barca-Velha
# 2    Washington                       Cayuse                     Bionic Frog
# 3      Victoria  Chambers Rosewood Vineyards                            Rare
# 4    Washington                Charles Smith                      Royal City
# 5          Port              Quinta do Noval                Nacional Vintage
# 6     Champagne                         Krug                            Brut
# 7     Champagne               Louis Roederer            Cristal Vintage Brut
# 8     Champagne                        Salon  Le Mesnil Blanc de Blancs Brut
#
#       variety_name     taster_name taster_twitter_handle
# 0       Sangiovese   Kerin O’Keefe          @kerinokeefe
# 1   Portuguese Red      Roger Voss            @vossroger
# 2            Syrah    Paul Gregutt           @paulgwine
# 3           Muscat  Joe Czerwinski                @JoeCz
# 4            Syrah    Paul Gregutt           @paulgwine
# 5             Port      Roger Voss            @vossroger
# 6  Champagne Blend      Roger Voss            @vossroger
# 7  Champagne Blend      Roger Voss            @vossroger
# 8       Chardonnay      Roger Voss            @vossroger

# %% [markdown]
# **Question 3**: List most commonly occuring Unique Varieties, their Review Counts, and Highest Points per Variety:

# %%
# %%sql
# SELECT
#   v.variety_name,
#   COUNT(*) AS variety_count,
#   MAX(r.points) AS highest_points
# FROM Varieties v
# JOIN Reviews r ON v.variety_id = r.variety_id
# GROUP BY v.variety_name
# HAVING variety_count > 10
# ORDER BY variety_count DESC;
# Out:
#  * mysql+pymysql://francis:***@localhost/wine_reviews
# 21 rows affected.
#                 variety_name  variety_count  highest_points
# 0                 Pinot Noir            222              98
# 1                 Chardonnay            155             100
# 2                   Riesling            154              97
# 3                   Nebbiolo            111              99
# 4         Cabernet Sauvignon             79              99
# 5   Bordeaux-style Red Blend             72              99
# 6                      Syrah             71             100
# 7            Champagne Blend             62             100
# 8                       Port             51             100
# 9                  Red Blend             45              99
# 10                Sangiovese             37             100
# 11            Portuguese Red             35             100
# 12                    Shiraz             27              99
# 13          Grüner Veltliner             24              96
# 14                    Malbec             20              97
# 15     Rhône-style Red Blend             15              98
# 16            Gewürztraminer             13              96
# 17                Pinot Gris             13              96
# 18               Tempranillo             12              97
# 19                 Zinfandel             12              97
# 20           Sparkling Blend             11              98

# %% [markdown]
# **Question 4**: Find the Highest rated wine by country:

# %%
# %%sql
# WITH RankedReviews AS (
#   SELECT
#     l.country_name,
#     l.province_name,
#     r.title AS highest_rated_wine,
#     r.points,
#     ROW_NUMBER() OVER (PARTITION BY l.country_name ORDER BY r.points DESC) AS rnk
#   FROM
#     Locations l
#     JOIN Reviews r ON l.location_id = r.location_id
# )
#
# SELECT
#   country_name AS Country,
#   province_name AS Province,
#   highest_rated_wine,
#   points
# FROM RankedReviews
# WHERE rnk = 1
# ORDER BY points DESC;
# Out:
#  * mysql+pymysql://francis:***@localhost/wine_reviews
# 14 rows affected.
#          Country          Province  \
# 0      Australia          Victoria
# 1         France         Champagne
# 2          Italy           Tuscany
# 3       Portugal             Douro
# 4             US        Washington
# 5        Austria        Burgenland
# 6          Spain    Northern Spain
# 7      Argentina  Mendoza Province
# 8        Germany             Pfalz
# 9        Hungary            Tokaji
# 10         Chile    Central Valley
# 11       England           England
# 12   New Zealand       Hawke's Bay
# 13  South Africa      Stellenbosch
#
#                                    highest_rated_wine  points
# 0   Chambers Rosewood Vineyards NV Rare Muscat (Ru...     100
# 1   Salon 2006 Le Mesnil Blanc de Blancs Brut Char...     100
# 2   Biondi Santi 2010 Riserva  (Brunello di Montal...     100
# 3       Casa Ferreirinha 2008 Barca-Velha Red (Douro)     100
# 4   Charles Smith 2006 Royal City Syrah (Columbia ...     100
# 5   Kracher 2008 Zwischen den Seen Nummer 9 Trocke...      98
# 6   Emilio Moro 2009 Clon de la Familia  (Ribera d...      98
# 7   Bodega Catena Zapata 2006 Nicasia Vineyard Mal...      97
# 8   Müller-Catoir 2007 Breumel in den Mauren Trock...      97
# 9   Royal Tokaji 2013 6 Puttonyos Aszú Gold Label ...      97
# 10  Valdivieso NV Caballo Loco Number Sixteen Red ...      95
# 11  Nyetimber 2010 Blanc de Blancs Chardonnay (Eng...      95
# 12  Squawking Magpie 2014 SQM Gimblett Gravels Cab...      95
# 13      De Toren 2014 Book 17 XVII Red (Stellenbosch)      95

# %% [markdown]
# **Question 5**: Country stats

# %%
# %%sql
# SELECT
#   l.country_name AS Country,
#   COUNT(DISTINCT l.province_name) AS num_provinces,
#   COUNT(DISTINCT l.winery_name) AS num_wineries,
#   COUNT(DISTINCT l.designation_name) AS num_designations
# FROM Locations l
# LEFT JOIN Reviews r ON l.location_id = r.location_id
# GROUP BY l.country_name
# ORDER BY num_designations DESC;
# Out:
#  * mysql+pymysql://francis:***@localhost/wine_reviews
# 14 rows affected.
#          Country  num_provinces  num_wineries  num_designations
# 0             US              3           211               376
# 1         France             10           147               215
# 2          Italy              8           108               123
# 3        Austria             11            27                84
# 4       Portugal              6            39                46
# 5          Spain              4            23                34
# 6      Australia              2            20                31
# 7        Germany              4            15                21
# 8      Argentina              2            10                10
# 9        Hungary              1             4                 5
# 10       England              1             3                 3
# 11  South Africa              3             3                 3
# 12         Chile              2             2                 2
# 13   New Zealand              1             2                 2

# %% [markdown]
# ## 10. Save Data Files and SQL Scripts to GDrive Folder
# We copy the data and SQL scripts into our GDrive which will then be downloaded and migrated to the Coursera Lab.

# %%
# !cp $SCRIPT_PATH/*.sql $GD_SCRIPT_PATH/.
# !cp $DATA_PATH/*.csv $GD_DATA_PATH/.

# %% [markdown]
# ## 11. Migrate Data and Codes to Coursera Environment

# %% [markdown]
# ### Pre-Requisites
# - Data Files:
#   - <code>winemag-records.csv</code>
# - SQL Scripts:
#   - <code>setup-database.sql</code>, <code>create-tables.sql</code>, <code>load-dnorm-data.sql</code>, <code>ingest-data.sql</code>

# %% [markdown]
# ### MySQL Setup in Coursera
# **Step 1**: Using terminal, create new directories called <code>project</code> (if not already exist) and <code>wine_reviews</code>, where <code>wine_reviews</code> is a subdirectory of <code>project</code>.
#
# ```shell
# mkdir -p /home/coder/project
# mkdir -p /home/coder/project/wine_reviews
# ```
#
# **Step 2**: Create two directories called <code>data</code> and <code>scripts</code>, where <code>data</code> and <code>scripts</code> are subdirectory of <code>wine_reviews</code>.
#
# ```shell
# mkdir -p /home/coder/project/wine_reviews/data
# mkdir -p /home/coder/project/wine_reviews/scripts
# ```
# **Step 3**: Upload <code>winemag-records.csv</code> to the <code>data</code> folder and <code>setup-database.sql</code>, <code>load-data.sql</code>,<code>create-tables.sql</code> and <code>ingest-data.sql</code> to the <code>scripts</code> folder.

# %% [markdown]
# **Step 4**: In <code>bash</code> shell, create and configure a new database called <code>wine_reviews</code> and create a database user called <code>francis</code> and grant access to the <code>wine_reviews</code> database.
#
# ```shell
# mysql -t < /home/coder/project/wine_reviews/scripts/setup-database.sql
# ```
#
# Alternatively, in <code>MySQL shell</code>, we can also load the SQL script using
# ```shell
# SOURCE /home/coder/project/wine_reviews/scripts/setup-database.sql
# ```

# %% [markdown]
# **Step 5**: Open another terminal and launch MySQL console:
#
# ```shell
# mysql
# ```
# Then, verify if the database <code>wine_reviews</code> and user <code>francis</code> have been created as intended.
#
# ```shell
# SHOW DATABASES;
# SELECT user, host FROM mysql.user;
# ```

# %% [markdown]
# **Step 6**: In <code>bash</code> shell, load <code>dnorm-data.csv</code> into the </code>nutrition</code>.
#
# ```shell
# mysql -t < /home/coder/project/wine_reviews/scripts/load-dnorm-data.sql
# ```
#
# Or in <code>MySQL shell</code>, we can also load the SQL script using
# ```shell
# SOURCE /home/coder/project/wine_reviews/scripts/load-dnorm-data.sql
# ```
#
# In <code>MySQL</code> console verify the <code>csv</code> data has been correctly loaded into the <code>denormalised</code> table.
#
# ```shell
# USE wine_reviews;
# SELECT * FROM denormalised LIMIT 10;
# ```

# %% [markdown]
# **Step 7**: In <code>bash</code> shell, create all normalised data tables in the <code>wine_reviews</code> database.
#
# ```shell
# mysql -t < /home/coder/project/wine_reviews/scripts/create-tables.sql
# ```
#
# Or in <code>MySQL shell</code>, we can also load the SQL script using
# ```shell
# SOURCE /home/coder/project/wine_reviews/scripts/create-tables.sql
# ```
#
#
# In <code>MySQL</code> console, verify if the data tables have been created.
#
# ```shell
# SHOW TABLES;
# ```

# %% [markdown]
# **Step 8**: In <code>bash</code> shell, ingest data from the <code>pivot_tbl</code> table into the normalised data tables.
#
# ```shell
# mysql -t < /home/coder/project/wine_reviews/scripts/ingest-data.sql
# ```
#
# Or in <code>MySQL shell</code>, we can also load the SQL script using
# ```shell
# SOURCE /home/coder/project/wine_reviews/scripts/ingest-data.sql
# ```
#
# In <code>MySQL</code> console, verify if the data have been ingested as intended.
#
# ```shell
# SELECT * FROM Varieties LIMIT 10;
# ```
